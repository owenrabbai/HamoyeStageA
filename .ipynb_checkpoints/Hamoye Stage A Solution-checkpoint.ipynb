# %% [markdown]
# ## Exploratory Data Analysis on ........ Fuel Dataset
# ### Stage A of Hamoye Data Science Internship
# #### Fuel Quality Data Analysis Quiz
# ###### <i>Intern: Okolo Christian</i>
# <hr style="width:100%; height:1px; background: #000">

# %% [markdown]
# ##### Importing Important Libraries

# %%
import numpy as np    # For linear algebra
import pandas as pd   # For data processing

# Import plotting library
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rc('figure',figsize=(10,6))  # Container of width=10 and height=6 to hold our plots

# %% [markdown]
# #### Load the dataset

# %%
fuel_df = pd.read_csv('hamoye_fuel_data.csv')

# %%
fuel_df.head(3)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# 2               24.130                      39.72
#
#    fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 0                         18.53                1.121
# 1                         18.53                1.120
# 2                         38.12                1.650

# %% [markdown]
# <hr style="width:100%; height:1px; background: #000">
#
# ### Question 1: Modal Fuel Unit

# %%
# Get the most occurring element in fuel_unit
# modal_fuel_unit = fuel_df.fuel_unit.value_counts().nlargest(1)
modal_fuel_unit = fuel_df.fuel_unit.mode()[0]
print(modal_fuel_unit)
# Out:
# mcf

# %% [markdown]
# <hr style="width:100%; height:1px; background: #000">
#
# ### Question 2: Check the missing values in fuel_unit it up with answer from 1 above

# %%
# Check for missing values in fuel_unit
fuel_unit_missing = fuel_df.fuel_unit.isna().sum()
print("Fuel unit has {} missing values".format(fuel_unit_missing))
# Out:
# Fuel unit has 180 missing values

# %%
# Fill the missing values with the modal value
fuel_df['fuel_unit'] = fuel_df['fuel_unit'].fillna(value=modal_fuel_unit)
fuel_df.fuel_unit.isna().sum()
# Out:
# 0

# %% [markdown]
# <hr style="width:100%; height:1px; background: #000">
#
# ### Question 3: Correlation

# %%
# Plot the heatmap of the dataframe using seaborn
matrix = np.triu(fuel_df.corr())
sns.heatmap(fuel_df.corr(), annot=True, linewidths=0.05, linecolor='111')
